# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("cardio_train.csv")

df
# Out:
#           id    age gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393      M     168    62.0    110     80            1     1
# 1          1  20228      F     156    85.0    140     90            3     1
# 2          2  18857      F     165    64.0    130     70            3     1
# 3          3  17623      M     169    82.0    150    100            1     1
# 4          4  17474      F     156    56.0    100     60            1     1
# ...      ...    ...    ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240      M     168    76.0    120     80            1     1
# 69996  99995  22601      F     158   126.0    140     90            2     2
# 69997  99996  19066      M     183   105.0    180     90            3     1
# 69998  99998  22431      F     163    72.0    135     80            1     2
# 69999  99999  20540      F     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df['age'] =  ( round(df['age'] / 365, 0)).astype(int)

df = df.drop(columns=['id'])

# %%
df.head()
# Out:
#    age gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   50      M     168    62.0    110     80            1     1      0     0
# 1   55      F     156    85.0    140     90            3     1      0     0
# 2   52      F     165    64.0    130     70            3     1      0     0
# 3   48      M     169    82.0    150    100            1     1      0     0
# 4   48      F     156    56.0    100     60            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
df.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=70000, step=1)

# %%
df.describe()
# Out:
#                 age        height        weight         ap_hi         ap_lo  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.338686    164.359229     74.205690    126.654871     80.381600
# std        6.765294      8.210126     14.395757     18.196496     12.771848
# min       30.000000     55.000000     10.000000      1.000000      0.000000
# 25%       48.000000    159.000000     65.000000    120.000000     80.000000
# 50%       54.000000    165.000000     72.000000    120.000000     80.000000
# 75%       58.000000    170.000000     82.000000    140.000000     90.000000
# max       65.000000    250.000000    200.000000    240.000000    190.000000
#
#         cholesterol          gluc         smoke          alco        active  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean       1.366871      1.226457      0.088129      0.053771      0.803729
# ...

# %%
df.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
sb.histplot(df['age'], kde=True)
plt.title('Distribution of Age')
plt.show()

# %%
sb.pairplot(df[['height', 'weight', 'ap_hi', 'ap_lo']])
plt.show()

# %%
plt.figure(figsize=(10, 6))

# %%
sb.histplot(df['height'], kde=True)
plt.title('Distribution of Height')
plt.show()

# %%
sb.histplot(df['weight'], kde=True)
plt.title('Distribution of Weight')
plt.show()

# %%
sb.histplot(df['ap_hi'], kde=True)
plt.title('Distribution of Systolic BP')
plt.show()

# %%
sb.histplot(df['ap_lo'], kde=True)
plt.title('Distribution of Diastolic BP')
plt.show()

# %%
sb.histplot(df['gluc'], kde=True)
plt.title('Distribution of Glucose')
plt.show()

# %%
sb.histplot(df['smoke'], kde=True)
plt.title('Distribution of Smoking rate')
plt.show()

# %%
sb.histplot(df['alco'], kde=True)
plt.title('Distribution of Alcohol rate')
plt.show()

# %%
sb.histplot(df['active'], kde=True)
plt.title('Distribution of Active rate')
plt.show()

# %%
sb.scatterplot(data=df, x='weight', y='ap_hi')
plt.title('Scatter Plot of Systolic BP vs Weight')
plt.xlabel('Age')
plt.ylabel('Weight')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sb.boxplot(data=df.drop(columns=['age', 'height', 'weight', 'ap_hi', 'ap_lo']), orient="v")
plt.title('Boxplots of Cardiovascular Data Part 2/2')
plt.xlabel('Values')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report



X = df.drop(columns=['cardio', 'gender'])
Y = df['cardio']


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)


model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
print("Marginal Error:", accuracy)
print(classification_report(Y_test, Y_pred))
# Out:
# Accuracy: 0.7054285714285714
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.71      6988
#            1       0.71      0.70      0.70      7012
#
#     accuracy                           0.71     14000
#    macro avg       0.71      0.71      0.71     14000
# weighted avg       0.71      0.71      0.71     14000

# %%
df['gender'] = df['gender'].map({'M': 0, 'F': 1})
corr_matrix = df.corr()

plt.figure(figsize=(10, 8))


cmap = sb.diverging_palette(220, 10, as_cmap=True)

sb.heatmap(corr_matrix, cmap=cmap, annot=True, fmt=".2f", center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix')
plt.show()
